# %% [markdown]
# #Theory Questions

# %% [markdown]
# #1.What is Object-Oriented Programming (OOP)?

# %% [markdown]
# -> Object-Oriented Programming (OOP) is a programming style where code is organized into objects that combine data (attributes) and functions (methods).
# It focuses on concepts like class, object, encapsulation, inheritance, polymorphism, and abstraction to make code reusable, modular, and easy to maintain.

# %% [markdown]
# #2. What is a class in OOP?

# %% [markdown]
# -> In OOP, a class is a blueprint or template for creating objects.
# It defines the attributes (data/properties) and methods (functions/behaviors) that the objects created from it will have.

# %% [markdown]
# #3. What is an object in OOP?

# %% [markdown]
# -> An object in OOP is an instance of a class that contains data (attributes) and functions (methods) to represent a real-world entity.

# %% [markdown]
# #4. What is the difference between abstraction and encapsulation?

# %% [markdown]
# -> Abstraction → Hides implementation details and shows only the essential features. (Focus on what an object does, not how it does it.)
#
# Encapsulation → Bundles data and methods together inside a class and restricts direct access to them. (Focus on data hiding and protection.)

# %% [markdown]
# #5. What are dunder methods in Python?

# %% [markdown]
# -> Dunder methods are special double-underscore methods that let classes interact with Python’s built-in functions and operators.

# %% [markdown]
# #5. What are dunder methods in Python?

# %% [markdown]
# -> Dunder methods are special double-underscore methods that let classes interact with Python’s built-in functions and operators.

# %% [markdown]
# #6. Explain the concept of inheritance in OOP?

# %% [markdown]
# -> Inheritance lets a class acquire attributes and methods from another class, enabling code reuse and extension.

# %% [markdown]
# #7. What is polymorphism in OOP?

# %% [markdown]
# -> Polymorphism in OOP means one thing with many forms — the same function or method name can behave differently depending on the object that calls it.

# %% [markdown]
# #8. How is encapsulation achieved in Python?

# %% [markdown]
# -> In Python, encapsulation is achieved by restricting direct access to class variables and methods, and controlling it through special methods (getters/setters).

# %% [markdown]
# #9. What is a constructor in Python?

# %% [markdown]
# -> In Python, a constructor is a special method called __init__ that automatically runs when an object of a class is created.

# %% [markdown]
# #10. What are class and static methods in Python?

# %% [markdown]
# -> Class Method → Works with the class (cls), can access/modify class variables.
#
# Static Method → Independent function inside a class, does not access self or cls.

# %% [markdown]
# #11. What is method overloading in Python? ans in short

# %% [markdown]
# -> Method overloading in Python means defining multiple methods with the same name but different parameters.

# %% [markdown]
# #12. What is method overriding in OOP?

# %% [markdown]
# -> Method overriding in OOP occurs when a child class defines a method with the same name and parameters as a method in its parent class, replacing the parent’s version to provide a new or modified behavior.

# %% [markdown]
# #13. What is a property decorator in Python?

# %% [markdown]
# -> A property decorator (@property) in Python is used to define getter methods that let you access a method like an attribute, without using parentheses.

# %% [markdown]
# #14. Why is polymorphism important in OOP?

# %% [markdown]
# -> Polymorphism is important in OOP because it allows different classes to use the same method name but perform different actions.

# %% [markdown]
# #15. What is an abstract class in Python?

# %% [markdown]
# -> An abstract class in Python is a class that cannot be instantiated directly and is used to define a common interface for its subclasses.

# %% [markdown]
# #16. What are the advantages of OOP?

# %% [markdown]
# ->Reusability -Code can be reused through inheritance.
#
# Modularity - Programs are divided into smaller, manageable parts (classes).
#
# Encapsulation - Data is protected from outside interference.
#
# Maintainability - Easier to update and modify code.
#
# Polymorphism - Same interface can work with different data types or classes.

# %% [markdown]
# #17. What is the difference between a class variable and an instance variable?

# %% [markdown]
# -> Class variable: Shared by all objects of a class; defined inside the class but outside methods.
# Instance variable: Unique to each object; defined inside methods (usually __init__) using self.

# %% [markdown]
# #18. What is multiple inheritance in Python?

# %% [markdown]
# -> Multiple inheritance in Python means a class can inherit from more than one parent class, allowing it to access attributes and methods from all parent classes.

# %% [markdown]
# #19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.

# %% [markdown]
# -> __str__ and __repr__ are special (dunder) methods used to define how an object is represented as a string:
#
# __str__ → Returns a readable, user-friendly string (used by print()).
#
# __repr__ → Returns a developer-friendly string for debugging (used in the interpreter).

# %% [markdown]
# #20. What is the significance of the ‘super()’ function in Python?

# %% [markdown]
# ->The super() function in Python is used to call a method from the parent class inside a child class.

# %% [markdown]
# #21. What is the significance of the __del__ method in Python?

# %% [markdown]
# ->The __del__ method in Python is a destructor that is called automatically when an object is deleted or goes out of scope.

# %% [markdown]
# #22. What is the difference between @staticmethod and @classmethod in Python?

# %% [markdown]
# -> staticmethod:
#
# Doesn’t use self or cls.
#
# Works like a normal function inside a class.
#
# Can’t access or modify class or instance data.
#
# classmethod:
#
# Takes cls as the first argument.
#
# Can access and modify class variables.
#
# Works at the class level, not the object level.

# %% [markdown]
# #23. How does polymorphism work in Python with inheritance?

# %% [markdown]
# ->In Python, polymorphism with inheritance means a child class can override a method from its parent class, and the same method call can behave differently depending on the object.

# %% [markdown]
# #24. What is method chaining in Python OOP?

# %% [markdown]
# ->Method chaining in Python OOP means calling multiple methods on the same object in a single line, where each method returns the object itself

# %% [markdown]
# #25. What is the purpose of the __call__ method in Python?

# %% [markdown]
# -> The __call__ method in Python lets an object be called like a function.

# %% [markdown]
# #Practical Questions

# %% [markdown]
# #1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# Create objects
a = Animal()
d = Dog()

# Call methods
a.speak()
d.speak()
# Out:
# Animal makes a sound
# Bark!

# %% [markdown]
# #2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

c = Circle(5)
r = Rectangle(4, 6)

print("Area of Circle:", c.area())
print("Area of Rectangle:", r.area())
# Out:
# Area of Circle: 78.5
# Area of Rectangle: 24

# %% [markdown]
# #3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery = battery_capacity

    def display_info(self):
        print(f"Type: {self.type}, Brand: {self.brand}, Battery: {self.battery} kWh")

e_car = ElectricCar("Four Wheeler", "Tesla", 75)
e_car.display_info()
# Out:
# Type: Four Wheeler, Brand: Tesla, Battery: 75 kWh

# %% [markdown]
# #4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

# %%
# Base class
class Bird:
    def fly(self):
        print("Some birds can fly.")

# Derived class 1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow can fly high!")

# Derived class 2
class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly.")

# Polymorphism in action
birds = [Sparrow(), Penguin()]

for bird in birds:
    bird.fly()
# Out:
# Sparrow can fly high!
# Penguin cannot fly.

# %% [markdown]
# #5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ₹{amount}")
        else:
            print("Invalid deposit amount")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: ₹{amount}")
        else:
            print("Insufficient balance or invalid amount")

    def check_balance(self):
        print(f"Current Balance: ₹{self.__balance}")

# Create object
account = BankAccount(1000)
account.deposit(500)
account.withdraw(300)
account.check_balance()
# Out:
# Deposited: ₹500
# Withdrawn: ₹300
# Current Balance: ₹1200

# %% [markdown]
# #6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
        print("Instrument is playing a sound")

class Guitar(Instrument):
    def play(self):
        print("Guitar is playing strings")

class Piano(Instrument):
    def play(self):
        print("Piano is playing melody")

instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()
# Out:
# Guitar is playing strings
# Piano is playing melody

# %% [markdown]
# #7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print("Sum:", MathOperations.add_numbers(10, 5))
print("Difference:", MathOperations.subtract_numbers(10, 5))
# Out:
# Sum: 15
# Difference: 5

# %% [markdown]
# #8. Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

# Create objects
p1 = Person("Mimi")
p2 = Person("Bruno")
p3 = Person("Angshu")

print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %% [markdown]
# #9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Create object
f1 = Fraction(3, 4)
print(f1)
# Out:
# 3/4

# %% [markdown]
# #10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overload + operator
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"


v1 = Vector(3, 5)
v2 = Vector(2, 4)

v3 = v1 + v2
print("Resultant Vector:", v3)
# Out:
# Resultant Vector: (5, 9)

# %% [markdown]
# #11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Create object
p1 = Person("Mimi", 25)
p1.greet()
# Out:
# Hello, my name is Mimi and I am 25 years old.

# %% [markdown]
# #12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)


s1 = Student("Mimi", [85, 90, 78, 92])
print(f"{s1.name}'s Average Grade:", s1.average_grade())
# Out:
# Mimi's Average Grade: 86.25

# %% [markdown]
# #13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

# %%
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width
rect = Rectangle()
rect.set_dimensions(10, 5)
print("Area of Rectangle:", rect.area())
# Out:
# Area of Rectangle: 50

# %% [markdown]
# #14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


# Create objects
emp = Employee(40, 200)
mgr = Manager(40, 200, 5000)

print("Employee Salary:", emp.calculate_salary())
print("Manager Salary:", mgr.calculate_salary())
# Out:
# Employee Salary: 8000
# Manager Salary: 13000

# %% [markdown]
# #15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() thatcalculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

p1 = Product("Laptop", 50000, 2)
print(f"Total price of {p1.name}: ₹{p1.total_price()}")
# Out:
# Total price of Laptop: ₹100000

# %% [markdown]
# #16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

# %%
from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# Derived class 1
class Cow(Animal):
    def sound(self):
        print("Cow says Moo!")

# Derived class 2
class Sheep(Animal):
    def sound(self):
        print("Sheep says Baa!")

# Create objects
c = Cow()
s = Sheep()

c.sound()
s.sound()
# Out:
# Cow says Moo!
# Sheep says Baa!

# %% [markdown]
# #17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

# Create object
b1 = Book("Goods vives good life ", "Vex King", 1988)
print(b1.get_book_info())
# Out:
# 'Goods vives good life ' by Vex King, published in 1988

# %% [markdown]
# #18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def display_info(self):
        print(f"Address: {self.address}")
        print(f"Price: ₹{self.price}")
        print(f"Number of Rooms: {self.number_of_rooms}")


m1 = Mansion("123 Park Street", 50000000, 10)
m1.display_info()
# Out:
# Address: 123 Park Street
# Price: ₹50000000
# Number of Rooms: 10
